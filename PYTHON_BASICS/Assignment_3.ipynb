# %% [markdown]
# # Assignment_3

# %% [markdown]
# ## 1\. Why are functions advantageous to have in your programs?

# %% [markdown]
# **ANS:**
# - A function is a block of code which only runs when it is called.
# - Reusability of code when it is needed.
# - Avoid duplication of code.
# - Easy to read, Breaking the code in smaller function.

# %% [markdown]
# ## 2\. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# **ANS:**
# - The code in a function run when **it is called**.

# %% [markdown]
# ## 3\. What statement creates a function?

# %% [markdown]
# **ANS:**
# - The **def** keyword is a statement for defining a function in Python.
# - syntax of function:
#   ```python
#   def function_name(parameters):
# 	"""docstring"""
# 	statement(s)
#   ```

# %% [markdown]
# ## 4\. What is the difference between a function and a function call?

# %% [markdown]
# **ANS:**
# - **Function:** It is block of code which only runs when it is called.
# - **Function call:** To run a function we need to call/invoke/use the function.
# To call the function we write the name of the function and then, followed in parentheses, argument values if any that are needed.

# %% [markdown]
# ## 5\. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# **ANS:**
# - **global scope**
#   - There is only **one** global scope per program execution.
#   - This scope remains in existence until the program terminates and all its names are forgotten.
# - **local scope**
#   - There can be **many** local scopes.
#   - It is created at function call.
#   - A variable created inside a function belongs to the local scope of that function, and can only be used inside that function.

# %% [markdown]
# ## 6\. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# **ANS:**
# - Each call of the function creates new local variables, and their lifetimes expire when the function returns to the caller.
# - Means When a function returns, the local scope is destroyed, and all the variables in it are forgotten

# %% [markdown]
# ## 7\. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# **ANS:**
# - A return value is the value that a function call evaluates to. Like any value, a return value can be used as part of an expression.

# %% [markdown]
# ## 8\. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# **ANS:**
# - If there is no return statement for a function, its return value is `None`.

# %%
def myfunc():
  print("This is body of function")

print(type(myfunc()))
# Out:
# This is body of function
# <class 'NoneType'>

# %% [markdown]
# ## 9\. How do you make a function variable refer to the global variable?

# %% [markdown]
# **ANS:**
# - Normally, when you create a variable inside a function, that variable is local, and can only be used inside that function.
# - To create a global variable inside a function, you can use the `global` keyword.

# %%
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %% [markdown]
# ## 10\. What is the data type of None?

# %% [markdown]
# **ANS:**
# - The `None` keyword is used to define a null value, or no value at all.
# - The data type of `None` is `NoneType`.

# %%
var = None

print(type(var))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ## 11\. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# **ANS:**
# - That `import` statement imports a module named areallyourpetsnamederic. (This isn't a real Python module, by the way.)

# %% [markdown]
# ## 12\. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# **ANS:**
# - This function can be called with `spam.bacon()`.

# %% [markdown]
# ## 13\. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# **ANS:**
# - Place the line of code that might cause an error in a `try` clause and use `except` block to handle the error.

# %% [markdown]
# ## 14\. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# **ANS:**
# - The `try` block lets you test a block of code for errors. The `except` block lets you handle the error.

# %%
try:
  print(10/0)
except:
  print("An exception occurred")
# Out:
# An exception occurred
